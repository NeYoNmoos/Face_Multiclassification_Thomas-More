# %%
def preprocess_face(face_img, target_size=(224, 224)):
    """Preprocess face image for model training."""
    try:
        if face_img is None or face_img.size == 0:
            return None
            
        # Convert to RGB if needed
        if len(face_img.shape) == 2:
            face_img = cv2.cvtColor(face_img, cv2.COLOR_GRAY2RGB)
        elif face_img.shape[2] == 4:
            face_img = cv2.cvtColor(face_img, cv2.COLOR_BGRA2RGB)
        elif face_img.shape[2] == 3:
            face_img = cv2.cvtColor(face_img, cv2.COLOR_BGR2RGB)
            
        # Resize while maintaining aspect ratio
        aspect_ratio = face_img.shape[1] / face_img.shape[0]
        if aspect_ratio > 1:
            # Width is larger
            new_width = target_size[0]
            new_height = int(new_width / aspect_ratio)
        else:
            # Height is larger
            new_height = target_size[1]
            new_width = int(new_height * aspect_ratio)
            
        resized = cv2.resize(face_img, (new_width, new_height), interpolation=cv2.INTER_AREA)
        
        # Create blank canvas
        final_img = np.zeros((target_size[0], target_size[1], 3), dtype=np.uint8)
        
        # Center the image
        y_offset = (target_size[0] - new_height) // 2
        x_offset = (target_size[1] - new_width) // 2
        
        final_img[y_offset:y_offset+new_height, x_offset:x_offset+new_width] = resized
        
        return final_img
        
    except Exception as e:
        print(f"Error preprocessing face: {str(e)}")
        return None

# Update the face processing part in extract_and_save_faces
def extract_and_save_faces(images, labels, output_folder, batch_size=50, target_size=(224, 224)):
    """Extract faces from images and save them preprocessed into corresponding label folders."""
    os.makedirs(output_folder, exist_ok=True)
    
    for batch_start in range(0, len(images), batch_size):
        
        batch_images = images[batch_start:batch_start + batch_size]
        batch_labels = labels[batch_start:batch_start + batch_size]
        
        for (filename, image), image_labels in zip(batch_images, batch_labels):
            print(f"Processing {filename}...")
            
            if image_labels == ["nothing"]:
                continue
                
            rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            face_boxes = detect_faces(rgb_image)
            
            if len(face_boxes) != len(image_labels):
                detections = detector.detect_faces(rgb_image)
                face_boxes = sorted(
                    [d['box'] for d in detections if d['confidence'] > 0.85],
                    key=lambda x: x[0]
                )
                
                if len(face_boxes) != len(image_labels):
                    print(f"Skipping {filename} - Could not match face count")
                    continue
            
            for i, (box, label) in enumerate(zip(face_boxes, image_labels)):
                x, y, width, height = box
                
                # Add margin
                margin = int(max(width, height) * 0.2)
                x = max(0, x - margin)
                y = max(0, y - margin)
                width = min(width + 2*margin, image.shape[1] - x)
                height = min(height + 2*margin, image.shape[0] - y)
                
                face = image[y:y+height, x:x+width]
                
                if face.size == 0 or face.shape[0] < 50 or face.shape[1] < 50:
                    print(f"Warning: Face too small in {filename}")
                    continue
                
                # Preprocess face
                processed_face = preprocess_face(face, target_size)
                if processed_face is None:
                    print(f"Warning: Could not process face in {filename}")
                    continue
                
                # Save processed face
                label_folder = os.path.join(output_folder, label.lower())
                os.makedirs(label_folder, exist_ok=True)
                
                face_filename = f"{os.path.splitext(filename)[0]}_face_{i}.jpg"
                cv2.imwrite(os.path.join(label_folder, face_filename), cv2.cvtColor(processed_face, cv2.COLOR_RGB2BGR))
        
        gc.collect()

# %%
import os
import cv2
import numpy as np
from mtcnn import MTCNN
import gc

# Initialize MTCNN
detector = MTCNN()

def load_images(image_folder, label_map=None):
    """
    Load images from a folder, optionally mapping filenames to labels.
    Args:
        image_folder: Path to the folder containing images.
        label_map: Optional dictionary mapping filenames to labels.
    Returns:
        images: List of (filename, image) tuples.
        labels: List of labels corresponding to the images (or None if no labels).
    """
    images = []
    image_labels = []

    for filename in os.listdir(image_folder):
        img_path = os.path.join(image_folder, filename)
        img = cv2.imread(img_path)

        if img is not None:
            images.append((filename, img))
            if label_map:
                image_labels.append(label_map.get(filename, []))  # Default to empty list for test images

    return images, image_labels if label_map else None

def detect_faces(image):
    """
    Detect faces in an image using MTCNN.
    Args:
        image: Input image (NumPy array).
    Returns:
        List of bounding boxes [(x, y, width, height)] for detected faces.
    """
    detections = detector.detect_faces(image)
    return [detection['box'] for detection in detections if detection['confidence'] > 0.9]

# def crop_and_save_faces(images, labels, output_folder, batch_size=50, resize_dim=(224, 224)):
#     """
#     Crop faces from images and save them into respective folders.
#     Args:
#         images: List of (filename, image) tuples.
#         labels: Corresponding labels for the images (or None for test images).
#         output_folder: Folder to save cropped faces.
#         batch_size: Number of images to process per batch.
#         resize_dim: Tuple (width, height) to resize cropped faces.
#     """
#     # Create default folder
#     default_folder = os.path.join(output_folder, "default")
#     os.makedirs(default_folder, exist_ok=True)

#     # Create folders for labeled faces if labels are provided
#     if labels:
#         for label_list in labels:
#             for label in label_list:
#                 label_folder = os.path.join(output_folder, label)
#                 os.makedirs(label_folder, exist_ok=True)

#     # Process images in batches
#     for batch_start in range(0, len(images), batch_size):
#         batch_end = batch_start + batch_size
#         batch_images = images[batch_start:batch_end]
#         batch_labels = labels[batch_start:batch_end] if labels else None

#         for idx, (filename, img) in enumerate(batch_images):
#             # Resize image for faster processing
#             img_resized = cv2.resize(img, (640, 480))

#             # Detect faces
#             faces = detect_faces(img_resized)

#             # Scale coordinates back to original image size
#             scale_x = img.shape[1] / img_resized.shape[1]
#             scale_y = img.shape[0] / img_resized.shape[0]
#             faces = [(int(x * scale_x), int(y * scale_y), int(w * scale_x), int(h * scale_y)) for x, y, w, h in faces]

#             # Sort faces by x-coordinate
#             sorted_faces = sorted(faces, key=lambda box: box[0])

#             # Save each detected face
#             for i, (x, y, w, h) in enumerate(sorted_faces):
#                 face = img[y:y + h, x:x + w]
#                 face_resized = cv2.resize(face, resize_dim)
                
#                 face_resized = cv2.cvtColor(face_resized, cv2.COLOR_BGR2GRAY)

#                 # Save to the default folder
#                 face_path_default = os.path.join(default_folder, f"{filename}_face_{i}.jpg")
#                 cv2.imwrite(face_path_default, face_resized)

#                 # Save to the respective label folders if labels are provided
#                 if labels and len(batch_labels[idx]) > i:
#                     person_label = batch_labels[idx][i]
#                     label_folder = os.path.join(output_folder, person_label)
#                     face_path_label = os.path.join(label_folder, f"{filename}_{person_label}_face_{i}.jpg")
#                     cv2.imwrite(face_path_label, face_resized)

#         # Clear memory after processing the batch
#         gc.collect()

# %%
def extract_and_save_test_faces(images, output_folder, target_size=(224, 224), batch_size=50):
    """Extract faces from test images and save them sequentially."""
    os.makedirs(output_folder, exist_ok=True)
    
    for batch_start in range(0, len(images), batch_size):
        batch_images = images[batch_start:batch_start + batch_size]
        
        for filename, image in batch_images:
            print(f"Processing {filename}...")
            
            # Convert BGR to RGB for MTCNN
            rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Detect faces and sort left-to-right
            detections = detector.detect_faces(rgb_image)
            face_boxes = sorted(
                [d['box'] for d in detections if d['confidence'] > 0.85],
                key=lambda x: x[0]
            )
            
            # Process each face
            for i, box in enumerate(face_boxes):
                x, y, width, height = box
                
                # Add margin
                margin = int(max(width, height) * 0.2)
                x = max(0, x - margin)
                y = max(0, y - margin)
                width = min(width + 2*margin, image.shape[1] - x)
                height = min(height + 2*margin, image.shape[0] - y)
                
                face = image[y:y+height, x:x+width]
                
                if face.size == 0 or face.shape[0] < 50 or face.shape[1] < 50:
                    print(f"Warning: Face too small in {filename}")
                    continue
                
                # Preprocess face
                processed_face = preprocess_face(face, target_size)
                if processed_face is None:
                    print(f"Warning: Could not process face in {filename}")
                    continue
                
                # Save processed face with sequential numbering
                face_filename = f"{os.path.splitext(filename)[0]}_face_{i}.jpg"
                cv2.imwrite(os.path.join(output_folder, face_filename), 
                           cv2.cvtColor(processed_face, cv2.COLOR_RGB2BGR))
            
            print(f"Found {len(face_boxes)} faces in {filename}")
        
        gc.collect()

test_images = []
test_folder = "../data/images/test_images/cleaned_images"
for filename in sorted(os.listdir(test_folder)):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        img_path = os.path.join(test_folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            test_images.append((filename, img))

output_folder = "../data/faces3_test"
extract_and_save_test_faces(test_images, output_folder)
# Out:
# Processing 0037.jpg...
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0037.jpg
# Processing 0039.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# Found 3 faces in 0039.jpg
# Processing 0040.jpg...
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 20ms/step
# Warning: Face too small in 0040.jpg
# Found 4 faces in 0040.jpg
# Processing 0043.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# Found 2 faces in 0043.jpg
# Processing 0045.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# Found 1 faces in 0045.jpg
# Processing 0051.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 0 faces in 0051.jpg
# Processing 0058.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0058.jpg
# Processing 0062.jpg...
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# Found 1 faces in 0062.jpg
# Processing 0066.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# Found 2 faces in 0066.jpg
# Processing 0078.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 12ms/step
# Found 1 faces in 0078.jpg
# Processing 0103.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0103.jpg
# Processing 0125.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0125.jpg
# Processing 0139.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0139.jpg
# Processing 0160.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 0 faces in 0160.jpg
# Processing 0161.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0161.jpg
# Processing 0166.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0166.jpg
# Processing 0168.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0168.jpg
# Processing 0174.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# Found 1 faces in 0174.jpg
# Processing 0179.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0179.jpg
# Processing 0182.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# Warning: Face too small in 0182.jpg
# Warning: Face too small in 0182.jpg
# Warning: Face too small in 0182.jpg
# Warning: Face too small in 0182.jpg
# Found 4 faces in 0182.jpg
# Processing 0194.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# Found 2 faces in 0194.jpg
# Processing 0221.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# Found 0 faces in 0221.jpg
# Processing 0226.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0226.jpg
# Processing 0233.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 14ms/step
# Found 1 faces in 0233.jpg
# Processing 0245.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0245.jpg
# Processing 0246.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Warning: Face too small in 0246.jpg
# Found 1 faces in 0246.jpg
# Processing 0255.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0255.jpg
# Processing 0262.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# Found 3 faces in 0262.jpg
# Processing 0268.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# Found 0 faces in 0268.jpg
# Processing 0275.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0275.jpg
# Processing 0282.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# Found 2 faces in 0282.jpg
# Processing 0316.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 20ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0316.jpg
# Processing 0344.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 0 faces in 0344.jpg
# Processing 0377.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Warning: Face too small in 0377.jpg
# Warning: Face too small in 0377.jpg
# Found 4 faces in 0377.jpg
# Processing 0381.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 7/7 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 21ms/step
# Warning: Face too small in 0381.jpg
# Found 4 faces in 0381.jpg
# Processing 0398.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# Found 3 faces in 0398.jpg
# Processing 0416.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# Found 1 faces in 0416.jpg
# Processing 0418.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Warning: Face too small in 0418.jpg
# Found 3 faces in 0418.jpg
# Processing 0420.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found
jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 17ms/step
# Found 2 faces in 0822.jpg
# Processing 0825.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 0 faces in 0825.jpg

# %%
def extract_and_save_test_faces(images, output_folder, target_size=(224, 224), batch_size=50):
    """Extract faces from test images and save them sequentially."""
    os.makedirs(output_folder, exist_ok=True)
    
    for batch_start in range(0, len(images), batch_size):
        batch_images = images[batch_start:batch_start + batch_size]
        
        for filename, image in batch_images:
            print(f"Processing {filename}...")
            
            # Convert BGR to RGB for MTCNN
            rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            
            # Detect faces and sort left-to-right
            detections = detector.detect_faces(rgb_image)
            face_boxes = sorted(
                [d['box'] for d in detections if d['confidence'] > 0.85],
                key=lambda x: x[0]
            )
            
            # If no faces are detected, create a fallback face crop
            if not face_boxes:
                print(f"No faces detected in {filename}. Using fallback.")
                h, w, _ = image.shape
                fallback_margin = int(min(h, w) * 0.1)  # 10% margin
                x = max(0, w // 4 - fallback_margin)
                y = max(0, h // 4 - fallback_margin)
                width = min(w // 2 + fallback_margin * 2, w - x)
                height = min(h // 2 + fallback_margin * 2, h - y)
                face_boxes = [[x, y, width, height]]

            # Process each face
            for i, box in enumerate(face_boxes):
                x, y, width, height = box
                
                # Add margin
                margin = int(max(width, height) * 0.2)
                x = max(0, x - margin)
                y = max(0, y - margin)
                width = min(width + 2 * margin, image.shape[1] - x)
                height = min(height + 2 * margin, image.shape[0] - y)
                
                face = image[y:y+height, x:x+width]
                
                if face.size == 0 or face.shape[0] < 50 or face.shape[1] < 50:
                    print(f"Warning: Face too small in {filename}")
                    continue
                
                # Preprocess face
                processed_face = preprocess_face(face, target_size)
                if processed_face is None:
                    print(f"Warning: Could not process face in {filename}")
                    continue
                
                # Save processed face with sequential numbering
                face_filename = f"{os.path.splitext(filename)[0]}_face_{i}.jpg"
                cv2.imwrite(os.path.join(output_folder, face_filename), 
                            cv2.cvtColor(processed_face, cv2.COLOR_RGB2BGR))
            
            print(f"Found {len(face_boxes)} faces in {filename}")


test_images = []
test_folder = "../data/images/test_images/cleaned_images"
for filename in sorted(os.listdir(test_folder)):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        img_path = os.path.join(test_folder, filename)
        img = cv2.imread(img_path)
        if img is not None:
            test_images.append((filename, img))

output_folder = "../data/faces4_test"
extract_and_save_test_faces(test_images, output_folder)
# Out:
# Processing 0037.jpg...
# 1/1 [==============================] - 0s 59ms/step
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f6384688820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 82ms/step
# Found 1 faces in 0037.jpg
# Processing 0039.jpg...
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# Found 3 faces in 0039.jpg
# Processing 0040.jpg...
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 5/5 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 22ms/step
# Warning: Face too small in 0040.jpg
# Found 4 faces in 0040.jpg
# Processing 0043.jpg...
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 2 faces in 0043.jpg
# Processing 0045.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 13ms/step
# Found 1 faces in 0045.jpg
# Processing 0051.jpg...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 15ms/step
# No faces detected in 0051.jpg. Using fallback.
# Found 1 faces in 0051.jpg
# Processing 0058.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0058.jpg
# Processing 0062.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0062.jpg
# Processing 0066.jpg...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# Found 2 faces in 0066.jpg
# Processing 0078.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 13ms/step
# Found 1 faces in 0078.jpg
# Processing 0103.jpg...
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0103.jpg
# Processing 0125.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0125.jpg
# Processing 0139.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 0139.jpg
# Processing 0160.jpg...
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# No faces detected in 0160.jpg. Using fallback.
# Found 1 faces in 0160.jpg
# Processing 0161.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 17ms/step
# Found 1 faces in 0161.jpg
# Processing 0166.jpg...
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 20ms/step
# Found 1 faces in 0166.jpg
# Processing 0168.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 1 faces in 
jpg...
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 18ms/step
# Warning: Face too small in 0621.jpg
# Found 1 faces in 0621.jpg
# Processing 0624.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# ...
# Warning: Face too small in 0669.jpg
# Warning: Face too small in 0669.jpg
# Found 4 faces in 0669.jpg
# Processing 0675.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Warning: Face too small in 0675.jpg
# Found 2 faces in 0675.jpg
# Processing 0676.jpg...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 18ms/step
# Found 2 faces in 0676.jpg
# Processing 0679.jpg...
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 19ms/step
# Warning: Face too small in 0679.jpg
# Found 2 faces in 0679.jpg
# Processing 0698.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Warning: Face too small in 0698.jpg
# Found 2 faces in 0698.jpg
# Processing 0754.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0754.jpg
# Processing 0757.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# Found 2 faces in 0757.jpg
# Processing 0763.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# Found 1 faces in 0763.jpg
# Processing 0764.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0764.jpg
# Processing 0765.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 3ms/step
# No faces detected in 0765.jpg. Using fallback.
# Found 1 faces in 0765.jpg
# Processing 0766.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 16ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 14ms/step
# No faces detected in 0766.jpg. Using fallback.
# Found 1 faces in 0766.jpg
# Processing 0770.jpg...
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 14ms/step
# No faces detected in 0770.jpg. Using fallback.
# Found 1 faces in 0770.jpg
# Processing 0772.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# No faces detected in 0772.jpg. Using fallback.
# Found 1 faces in 0772.jpg
# Processing 0779.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 3/3 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# Warning: Face too small in 0779.jpg
# Found 3 faces in 0779.jpg
# Processing 0786.jpg...
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 2/2 [==============================] - 0s 5ms/step
# 1/1 [==============================] - 0s 14ms/step
# Found 2 faces in 0786.jpg
# Processing 0790.jpg...
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 5/5 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# No faces detected in 0790.jpg. Using fallback.
# Found 1 faces in 0790.jpg
# Processing 0792.jpg...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 14ms/step
# No faces detected in 0792.jpg. Using fallback.
# Found 1 faces in 0792.jpg
# Processing 0794.jpg...
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 16ms/step
# Found 1 faces in 0794.jpg
# Processing 0799.jpg...
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 19ms/step
# No faces detected in 0799.jpg. Using fallback.
# Found 1 faces in 0799.jpg
# Processing 0805.jpg...
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# No faces detected in 0805.jpg. Using fallback.
# Found 1 faces in 0805.jpg
# Processing 0808.jpg...
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 3ms/step
# No faces detected in 0808.jpg. Using fallback.
# Found 1 faces in 0808.jpg
# Processing 0818.jpg...
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 4ms/step
# 1/1 [==============================] - 0s 19ms/step
# Warning: Face too small in 0818.jpg
# Found 2 faces in 0818.jpg
# Processing 0822.jpg...
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 17ms/step
# Found 2 faces in 0822.jpg
# Processing 0825.jpg...
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 2/2 [==============================] - 0s 3ms/step
# 1/1 [==============================] - 0s 15ms/step
# No faces detected in 0825.jpg. Using fallback.
# Found 1 faces in 0825.jpg

# %%
# # Usage

# test_image_folder = "../data/images/test_images/cleaned_images"
# output_folder = "../data/images/test_faces"

# images_test, labels = load_images(test_image_folder)

# print(images_test[0][0])
# print(labels)
# output_folder = "../data/faces3_test"
# extract_and_save_faces(images_test, labels, output_folder)

# print("Preprocessed faces have been saved to the respective folders.")
# Out:
# 0427.jpg
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 11
#       9 print(labels)
#      10 output_folder = "../data/faces3_test"
# ---> 11 extract_and_save_faces(images_test, labels, output_folder)
#      13 print("Preprocessed faces have been saved to the respective folders.")
#
# Cell In[4], line 51, in extract_and_save_faces(images, labels, output_folder, batch_size, target_size)
#      48 for batch_start in range(0, len(images), batch_size):
#      50     batch_images = images[batch_start:batch_start + batch_size]
# ---> 51     batch_labels = labels[batch_start:batch_start + batch_size]
#      53     for (filename, image), image_labels in zip(batch_images, batch_labels):
#      54         print(f"Processing {filename}...")
#
# TypeError: 'NoneType' object is not subscriptable

# %%
output_folder = "../data/faces3_test"
extract_and_save_faces(images, labels, output_folder, target_size=(224, 224))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 output_folder = "../data/faces3_test"
# ----> 2 extract_and_save_faces(images, labels, output_folder, target_size=(224, 224))
#
# NameError: name 'images' is not defined

# %%
# Paths
train_image_folder = "../data/olda_data/cleaned_images"
label_csv_path = "../data/labels/clean_data.csv"
output_folder = "../data/faces/train5_faces"

# Load label data
import pandas as pd
label_data = pd.read_csv(label_csv_path)
label_data['label_name'] = label_data['label_name'].apply(eval)  # Convert string to list
label_map = dict(zip(label_data['image'].astype(str).str.zfill(4) + ".jpg", label_data['label_name']))

# Load training images and labels
train_images, train_labels = load_images(train_image_folder, label_map=label_map)

# Crop and save faces
print("Processing training images...")
extract_and_save_faces(train_images, labels=train_labels, output_folder=output_folder, batch_size=50)
print("Cropped faces have been saved.")
# Out:
# Processing training images...
# Processing 0032.jpg...
# Processing 0195.jpg...
# Warning: Face too small in 0195.jpg
# Processing 0569.jpg...
# Processing 0601.jpg...
# Skipping 0601.jpg - Could not match face count
# Processing 0072.jpg...
# Processing 0703.jpg...
# Warning: Face too small in 0703.jpg
# Processing 0516.jpg...
# Skipping 0516.jpg - Could not match face count
# Processing 0387.jpg...
# Warning: Face too small in 0387.jpg
# Processing 0710.jpg...
# Processing 0427.jpg...
# Processing 0356.jpg...
# Processing 0463.jpg...
# Processing 0325.jpg...
# Processing 0235.jpg...
# Processing 0151.jpg...
# Skipping 0151.jpg - Could not match face count
# Processing 0281.jpg...
# Processing 0158.jpg...
# Processing 0590.jpg...
# Skipping 0590.jpg - Could not match face count
# Processing 0159.jpg...
# Processing 0155.jpg...
# Skipping 0155.jpg - Could not match face count
# Processing 0290.jpg...
# Skipping 0290.jpg - Could not match face count
# Processing 0135.jpg...
# Skipping 0135.jpg - Could not match face count
# Processing 0190.jpg...
# Processing 0626.jpg...
# Warning: Face too small in 0626.jpg
# Warning: Face too small in 0626.jpg
# Processing 0367.jpg...
# Processing 0042.jpg...
# Skipping 0042.jpg - Could not match face count
# Processing 0794.jpg...
# Processing 0130.jpg...
# Warning: Face too small in 0130.jpg
# Processing 0068.jpg...
# Skipping 0068.jpg - Could not match face count
# Processing 0046.jpg...
# Skipping 0046.jpg - Could not match face count
# Processing 0616.jpg...
# Skipping 0616.jpg - Could not match face count
# Processing 0600.jpg...
# Warning: Face too small in 0600.jpg
# Processing 0545.jpg...
# Skipping 0545.jpg - Could not match face count
# Processing 0497.jpg...
# Processing 0389.jpg...
# Processing 0424.jpg...
# Skipping 0424.jpg - Could not match face count
# Processing 0650.jpg...
# Processing 0477.jpg...
# Skipping 0477.jpg - Could not match face count
# Processing 0071.jpg...
# Processing 0261.jpg...
# Warning: Face too small in 0261.jpg
# Processing 0810.jpg...
# Skipping 0810.jpg - Could not match face count
# Processing 0399.jpg...
# Processing 0353.jpg...
# Processing 0475.jpg...
# Skipping 0475.jpg - Could not match face count
# Processing 0623.jpg...
# Skipping 0623.jpg - Could not match face count
# Processing 0338.jpg...
# Warning: Face too small in 0338.jpg
# Processing 0738.jpg...
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
# Warning: Face too small in 0738.jpg
#
# Processing 0693.jpg...
# Processing 0476.jpg...
# Skipping 0476.jpg - Could not match face count
# Processing 0679.jpg...
# Skipping 0679.jpg - Could not match face count
# Processing 0694.jpg...
# Processing 0461.jpg...
# Processing 0422.jpg...
# Processing 0586.jpg...
# Warning: Face too small in 0586.jpg
# Warning: Face too small in 0586.jpg
# Processing 0448.jpg...
# Skipping 0448.jpg - Could not match face count
# Processing 0450.jpg...
# Skipping 0450.jpg - Could not match face count
# Processing 0355.jpg...
# Processing 0744.jpg...
# Warning: Face too small in 0744.jpg
# Warning: Face too small in 0744.jpg
# Processing 0808.jpg...
# Processing 0216.jpg...
# Processing 0082.jpg...
# Warning: Face too small in 0082.jpg
# Warning: Face too small in 0082.jpg
# Warning: Face too small in 0082.jpg
# Warning: Face too small in 0082.jpg
# Processing 0340.jpg...
# Skipping 0340.jpg - Could not match face count
# Processing 0632.jpg...
# Skipping 0632.jpg - Could not match face count
# Processing 0175.jpg...
# Warning: Face too small in 0175.jpg
# Processing 0673.jpg...
# Skipping 0673.jpg - Could not match face count
# Processing 0793.jpg...
# Skipping 0793.jpg - Could not match face count
# Processing 0146.jpg...
# Skipping 0146.jpg - Could not match face count
# Cropped faces have been saved.

# %%
# Paths
test_image_folder = "../data/images/test_images/cleaned_images"
output_folder = "../data/images/test_faces"

# Load test images (no labels required)
test_images, _ = load_images(test_image_folder)

# Crop and save faces
print("Processing test images...")
crop_and_save_faces(test_images, labels=None, output_folder=output_folder, batch_size=50)
print("Cropped faces have been saved.")
# Out:
# Processing test images...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 10
#       8 # Crop and save faces
#       9 print("Processing test images...")
# ---> 10 crop_and_save_faces(test_images, labels=None, output_folder=output_folder, batch_size=50)
#      11 print("Cropped faces have been saved.")
#
# Cell In[8], line 77, in crop_and_save_faces(images, labels, output_folder, batch_size, resize_dim)
#      74 img_resized = cv2.resize(img, (640, 480))
#      76 # Detect faces
# ---> 77 faces = detect_faces(img_resized)
#      79 # Scale coordinates back to original image size
#      80 scale_x = img.shape[1] / img_resized.shape[1]
#
# Cell In[12], line 42, in detect_faces(image)
#      34 def detect_faces(image):
#      35     """
#      36     Detect faces in an image using MTCNN.
#      37     Args:
#    (...)
#      40         List of bounding boxes [(x, y, width, height)] for detected faces.
#      41     """
# ---> 42     detections = detector.detect_faces(image)
#      43     return [detection['box'] for detection in detections]
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/mtcnn/mtcnn.py:159, in MTCNN.detect_faces(self, image, fit_to_image, limit_boundaries_landmarks, box_format, output_type, postprocess, batch_stack_justification, **kwargs)
#     157     # Process images through each stage (PNet, RNet, ONet)
#     158     for stage in self.stages:
# --> 159         bboxes_batch = stage(bboxes_batch=bboxes_batch, images_normalized=images_normalized, images_oshapes=images_oshapes, **kwargs)
#     161 except tf.errors.InvalidArgumentError:  # No faces found
#     162     bboxes_batch = np.empty((0, 16))
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/mtcnn/stages/stage_pnet.py:92, in StagePNet.__call__(self, images_normalized, images_oshapes, min_face_size, min_size, scale_factor, threshold_pnet, nms_pnet1, nms_pnet2, **kwargs)
#      89 batch_size = images_normalized.shape[0]
#      91 # 3. Get proposals bounding boxes and confidence from the model (PNet)
# ---> 92 pnet_result = [self._model(s) for s in scales_result]
#      94 # 4. Generate bounding boxes per scale group
#      95 bboxes_proposals = [generate_bounding_box(result[0], result[1], threshold_pnet) for result in pnet_result]
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/mtcnn/stages/stage_pnet.py:92, in <listcomp>(.0)
#      89 batch_size = images_normalized.shape[0]
#      91 # 3. Get proposals bounding boxes and confidence from the model (PNet)
# ---> 92 pnet_result = [self._model(s) for s in scales_result]
#      94 # 4. Generate bounding boxes per scale group
#      95 bboxes_proposals = [generate_bounding_box(result[0], result[1], threshold_pnet) for result in pnet_result]
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/mtcnn/network/pnet.py:98, in PNet.call(self, inputs, *args, **kwargs)
#      95 x = self.prelu3(x)
#      97 # Outputs
# ---> 98 bbox_reg = self.conv4_1(x)
#      99 bbox_class = self.conv4_2(x)
#     101 return [bbox_reg, bbox_class]
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/layers/layer.py:899, in Layer.__call__(self, *args, **kwargs)
#     897         outputs = super().__call__(*args, **kwargs)
#     898 else:
# --> 899     outputs = super().__call__(*args, **kwargs)
#     900 # Change the layout for the layer output if needed.
#     901 # This is useful for relayout intermediate tensor in the model
#     902 # to achieve the optimal performance.
#     903 distribution = distribution_lib.distribution()
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:243, in BaseConv.call(self, inputs)
#     242 def call(self, inputs):
# --> 243     outputs = self.convolution_op(
#     244         inputs,
#     245         self.kernel,
#     246     )
#     247     if self.use_bias:
#     248         if self.data_format == "channels_last":
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:233, in BaseConv.convolution_op(self, inputs, kernel)
#     232 def convolution_op(self, inputs, kernel):
# --> 233     return ops.conv(
#     234         inputs,
#     235         kernel,
#     236         strides=list(self.strides),
#     237         padding=self.padding,
#     238         dilation_rate=self.dilation_rate,
#     239         data_format=self.data_format,
#     240     )
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/ops/nn.py:1183, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#    1179 if any_symbolic_tensors((inputs,)):
#    1180     return Conv(strides, padding, data_format, dilation_rate).symbolic_call(
#    1181         inputs, kernel
#    1182     )
# -> 1183 return backend.nn.conv(
#    1184     inputs, kernel, strides, padding, data_format, dilation_rate
#    1185 )
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:301, in conv(inputs, kernel, strides, padding, data_format, dilation_rate)
#     299     return _conv_xla()
#     300 else:
# --> 301     return _conv()
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:274, in conv.<locals>._conv()
#     272 def _conv():
#     273     tf_data_format = _convert_data_format(data_format, len(inputs.shape))
# --> 274     return tf.nn.convolution(
#     275         inputs,
#     276         kernel,
#     277         strides,
#     278         padding.upper(),
#     279         data_format=tf_data_format,
#     280         dilations=dilation_rate,
#     281     )
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/nn_ops.py:1186, in convolution_v2(input, filters, strides, padding, data_format, dilations, name)
#    1176 @tf_export("nn.convolution", v1=[])
#    1177 @dispatch.add_dispatch_support
#    1178 def convolution_v2(  # pylint: disable=missing-docstring
#    (...)
#    1184     dilations=None,
#    1185     name=None):
# -> 1186   return convolution_internal(
#    1187       input,  # pylint: disable=redefined-builtin
#    1188       filters,
#    1189       strides=strides,
#    1190       padding=padding,
#    1191       data_format=data_format,
#    1192       dilations=dilations,
#    1193       name=name)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/nn_ops.py:1319, in convolution_internal(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1316   else:
#    1317     op = conv1d
# -> 1319   return op(
#    1320       input,
#    1321       filters,
#    1322       strides,
#    1323       padding=padding,
#    1324       data_format=data_format,
#    1325       dilations=dilations,
#    1326       name=name)
#    1327 else:
#    1328   if channel_index == 1:
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/nn_ops.py:2793, in _conv2d_expanded_batch(input, filters, strides, padding, data_format, dilations, name)
#    2789 input_rank = input.shape.rank
#    2790 if input_rank is None or input_rank < 5:
#    2791   # We avoid calling squeeze_batch_dims to reduce extra python function
#    2792   # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2793   return gen_nn_ops.conv2d(
#    2794       input,
#    2795       filter=filters,
#    2796       strides=strides,
#    2797       padding=padding,
#    2798       data_format=data_format,
#    2799       dilations=dilations,
#    2800       name=name)
#    2801 return squeeze_batch_dims(
#    2802     input,
#    2803     functools.partial(
#    (...)
#    2810     inner_rank=3,
#    2811     name=name)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_nn_ops.py:1345, in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1343   pass
#    1344 try:
# -> 1345   return conv2d_eager_fallback(
#    1346       input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#    1347       padding=padding, explicit_paddings=explicit_paddings,
#    1348       data_format=data_format, dilations=dilations, name=name, ctx=_ctx)
#    1349 except _core._SymbolicException:
#    1350   pass  # Add nodes to the TensorFlow graph.
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_nn_ops.py:1428, in conv2d_eager_fallback(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name, ctx)
#    1424   raise TypeError(
#    1425       "Expected list for 'dilations' argument to "
#    1426       "'conv2d' Op, not %r." % dilations)
#    1427 dilations = [_execute.make_int(_i, "dilations") for _i in dilations]
# -> 1428 _attr_T, _inputs_T = _execute.args_to_matching_eager([input, filter], ctx, [_dtypes.half, _dtypes.bfloat16, _dtypes.float32, _dtypes.float64, _dtypes.int32, ])
#    1429 (input, filter) = _inputs_T
#    1430 _inputs_flat = [input, filter]
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:267, in args_to_matching_eager(***failed resolving arguments***)
#     265       dtype = tensor.dtype
#     266 else:
# --> 267   ret = [tensor_conversion_registry.convert(t, dtype) for t in l]
#     269 # TODO(slebedev): consider removing this as it leaks a Keras concept.
#     270 # pylint: disable=protected-access
#     271 keras_symbolic_tensors = [x for x in ret if _is_keras_symbolic_tensor(x)]
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:267, in <listcomp>(.0)
#     265       dtype = tensor.dtype
#     266 else:
# --> 267   ret = [tensor_conversion_registry.convert(t, dtype) for t in l]
#     269 # TODO(slebedev): consider removing this as it leaks a Keras concept.
#     270 # pylint: disable=protected-access
#     271 keras_symbolic_tensors = [x for x in ret if _is_keras_symbolic_tensor(x)]
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:209, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     207 overload = getattr(value, "__tf_tensor__", None)
#     208 if overload is not None:
# --> 209   return overload(dtype, name)  #  pylint: disable=not-callable
#     211 for base_type, conversion_func in get(type(value)):
#     212   # If dtype is None but preferred_dtype is not None, we try to
#     213   # cast to preferred_dtype first.
#     214   ret = None
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/core.py:85, in Variable.__tf_tensor__(self, dtype, name)
#      84 def __tf_tensor__(self, dtype=None, name=None):
# ---> 85     return tf.convert_to_tensor(self.value, dtype=dtype, name=name)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/util/dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/tensor_conversion.py:161, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#      96 @tf_export.tf_export("convert_to_tensor", v1=[])
#      97 @dispatch.add_dispatch_support
#      98 def convert_to_tensor_v2_with_dispatch(
#      99     value, dtype=None, dtype_hint=None, name=None
#     100 ) -> tensor_lib.Tensor:
#     101   """Converts the given `value` to a `Tensor`.
#     102
#     103   This function converts Python objects of various types to `Tensor`
#    (...)
#     159     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#     160   """
# --> 161   return convert_to_tensor_v2(
#     162       value, dtype=dtype, dtype_hint=dtype_hint, name=name
#     163   )
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/tensor_conversion.py:171, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#     169 """Converts the given `value` to a `Tensor`."""
#     170 # preferred_dtype = preferred_dtype or dtype_hint
# --> 171 return tensor_conversion_registry.convert(
#     172     value, dtype, name, preferred_dtype=dtype_hint
#     173 )
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:2375, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2374 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2375   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:1621, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1619   return self.read_value().op.inputs[0]
#    1620 else:
# -> 1621   return self.value()
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:656, in BaseResourceVariable.value(self)
#     654   return self._cached_value
#     655 with ops.colocate_with(None, ignore_existing=True):
# --> 656   return self._read_variable_op()
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:841, in BaseResourceVariable._read_variable_op(self, no_copy)
#     839       result = read_and_set_handle(no_copy)
#     840 else:
# --> 841   result = read_and_set_handle(no_copy)
#     843 if not context.executing_eagerly():
#     844   # Note that if a control flow context is active the input of the read op
#     845   # might not actually be the handle. This line bypasses it.
#     846   record.record_operation(
#     847       "ReadVariableOp", [result], [self.handle],
#     848       backward_function=lambda x: [x],
#     849       forward_function=lambda x: [x])
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:831, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     829 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     830   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 831 result = gen_resource_variable_ops.read_variable_op(
#     832     self.handle, self._dtype)
#     833 _maybe_set_handle_data(self._dtype, self.handle, result)
#     834 return result
#
# File ~/thomas_more/ai_frameworks/Face_Multiclassifier_Project/.venv/lib/python3.10/site-packages/tensorflow/python/ops/gen_resource_variable_ops.py:534, in read_variable_op(resource, dtype, name)
#     532 if tld.is_eager:
#     533   try:
# --> 534     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     535       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     536     return _result
#     537   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print(len(train_labels))
# Out:
# 831
