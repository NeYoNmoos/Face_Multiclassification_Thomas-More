# %%
import os
import cv2
import numpy as np

# Function to apply random transformations to an image
def random_transform(img):
    rows, cols = img.shape

    # Random rotation
    angle = np.random.uniform(-30, 30)
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)
    img = cv2.warpAffine(img, M, (cols, rows), borderMode=cv2.BORDER_REFLECT)

    # Random translation
    tx = np.random.uniform(-0.3 * cols, 0.3 * cols)
    ty = np.random.uniform(-0.3 * rows, 0.3 * rows)
    M = np.float32([[1, 0, tx], [0, 1, ty]])
    img = cv2.warpAffine(img, M, (cols, rows), borderMode=cv2.BORDER_REFLECT)

    return img

# Function to load and preprocess training data
def load_training_data(data_folder, target_size=(224, 224)):
    images = []
    labels = []
    label_map = {}
    current_label = 0

    for person_name in os.listdir(data_folder):
        person_folder = os.path.join(data_folder, person_name)
        if os.path.isdir(person_folder):
            label_map[current_label] = person_name
            for filename in os.listdir(person_folder):
                img_path = os.path.join(person_folder, filename)
                img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
                if img is not None:
                    img_resized = cv2.resize(img, target_size)
                    augmented_imgs = [img_resized] + [
                        random_transform(img_resized) for _ in range(5)
                    ]
                    images.extend(augmented_imgs)
                    labels.extend([current_label] * len(augmented_imgs))
            current_label += 1

    return np.array(images), np.array(labels), label_map



# Path to the cropped faces folder
data_folder = "../data/faces3"

# Load training data
images, labels, label_map = load_training_data(data_folder)

print(f"Loaded {len(images)} images for training.")
print("Label Map:", label_map)

# Ensure images are in uint8 format (required for OpenCV)
images = images.astype('uint8')

# Train the LBPHFaceRecognizer model
recognizer = cv2.face.LBPHFaceRecognizer_create(radius=2, neighbors=8, grid_x=8, grid_y=8)

print("Training the LBPHFaceRecognizer model...")
recognizer.train(images, np.array(labels))

# Save the trained model
model_path = "../data/lbph_model.yml"
recognizer.write(model_path)
print(f"Model saved to {model_path}")
# Out:
# Loaded 3666 images for training.
# Label Map: {0: 'matthias', 1: 'lasse', 2: 'akif', 3: 'bart', 4: 'florian', 5: 'daiane', 6: 'konrad', 7: 'senne', 8: 'michiel', 9: 'seppe', 10: 'youssef', 11: 'raul', 12: 'alper', 13: 'nelli'}
# Training the LBPHFaceRecognizer model...
# Model saved to ../data/lbph_model.yml

# %%
def predict_faces_on_folder(model_path, test_faces_folder, label_map):
    """
    Predict the labels of all faces in a folder using the trained LBPH model.
    Args:
        model_path: Path to the saved LBPH model.
        test_faces_folder: Path to the folder containing test face images.
        label_map: Dictionary mapping integer labels to person names.
    Returns:
        results: List of dictionaries with filename, predicted label, and confidence.
    """
    # Load the trained model
    recognizer = cv2.face.LBPHFaceRecognizer_create()
    recognizer.read(model_path)

    results = []

    for filename in os.listdir(test_faces_folder):
        test_image_path = os.path.join(test_faces_folder, filename)
        
        # Load and preprocess the test image
        
        test_img = cv2.imread(test_image_path, cv2.IMREAD_GRAYSCALE)
        if test_img is None:
            print(f"Failed to read {test_image_path}, skipping.")
            continue

        test_img_resized = cv2.resize(test_img, (224, 224))  # Resize to match training size

        # Predict the label
        label, confidence = recognizer.predict(test_img_resized)
        person_name = label_map[label]
        results.append({
            "filename": filename,
            "predicted_label": person_name,
            "confidence": confidence
        })

    return results

# %%
# Paths
model_path = "../data/lbph_model.yml"
test_faces_folder = "../data/faces4_test"
# label_map = {0: "senne", 1: "youssef", 2: "akif"}  # Update with your actual label map

# Predict on all test faces
results = predict_faces_on_folder(model_path, test_faces_folder, label_map)

# %%
# Sort results by filename
results = sorted(results, key=lambda x: x['filename'])

# Print results
print("Test Results:")
for result in results:
    print(f"Filename: {result['filename']}, Predicted: {result['predicted_label']}, Confidence: {result['confidence']}")
# Out:
# Test Results:
# Filename: 0037_face_0.jpg, Predicted: senne, Confidence: 58.275749855816414
# Filename: 0039_face_0.jpg, Predicted: senne, Confidence: 73.45496818371741
# Filename: 0039_face_1.jpg, Predicted: youssef, Confidence: 58.0842313745586
# Filename: 0039_face_2.jpg, Predicted: matthias, Confidence: 60.14213389760546
# Filename: 0040_face_0.jpg, Predicted: seppe, Confidence: 69.08402443532239
# Filename: 0040_face_1.jpg, Predicted: alper, Confidence: 51.54332270470053
# Filename: 0040_face_3.jpg, Predicted: seppe, Confidence: 70.90705423599509
# Filename: 0043_face_0.jpg, Predicted: seppe, Confidence: 93.61705197459358
# Filename: 0043_face_1.jpg, Predicted: michiel, Confidence: 73.16671000477042
# Filename: 0045_face_0.jpg, Predicted: alper, Confidence: 70.67723281493001
# Filename: 0051_face_0.jpg, Predicted: youssef, Confidence: 85.3638853885874
# Filename: 0058_face_0.jpg, Predicted: bart, Confidence: 66.0778096481179
# Filename: 0062_face_0.jpg, Predicted: konrad, Confidence: 79.23217776571477
# Filename: 0066_face_0.jpg, Predicted: seppe, Confidence: 69.53032411442614
# Filename: 0066_face_1.jpg, Predicted: matthias, Confidence: 63.459329404086176
# Filename: 0078_face_0.jpg, Predicted: youssef, Confidence: 71.9201667846909
# Filename: 0103_face_0.jpg, Predicted: nelli, Confidence: 63.37504929310521
# Filename: 0125_face_0.jpg, Predicted: raul, Confidence: 79.05639988146186
# Filename: 0139_face_0.jpg, Predicted: youssef, Confidence: 62.27882590009698
# Filename: 0160_face_0.jpg, Predicted: youssef, Confidence: 78.94919017474481
# Filename: 0161_face_0.jpg, Predicted: florian, Confidence: 43.108357696546506
# Filename: 0166_face_0.jpg, Predicted: akif, Confidence: 62.02390903979299
# Filename: 0168_face_0.jpg, Predicted: konrad, Confidence: 43.40523153119042
# Filename: 0174_face_0.jpg, Predicted: bart, Confidence: 66.38402899470036
# Filename: 0179_face_0.jpg, Predicted: alper, Confidence: 68.46514245780993
# Filename: 0194_face_0.jpg, Predicted: seppe, Confidence: 63.548968190568225
# Filename: 0194_face_1.jpg, Predicted: seppe, Confidence: 56.66549977315287
# Filename: 0221_face_0.jpg, Predicted: konrad, Confidence: 75.0985819255154
# Filename: 0226_face_0.jpg, Predicted: senne, Confidence: 64.64308750232449
# Filename: 0233_face_0.jpg, Predicted: matthias, Confidence: 71.83894999840787
# Filename: 0245_face_0.jpg, Predicted: seppe, Confidence: 68.58352219735613
# Filename: 0255_face_0.jpg, Predicted: nelli, Confidence: 65.84256418249383
# Filename: 0262_face_0.jpg, Predicted: raul, Confidence: 70.51880129259854
# Filename: 0262_face_1.jpg, Predicted: youssef, Confidence: 60.49183093710676
# Filename: 0262_face_2.jpg, Predicted: matthias, Confidence: 58.67534801131165
# Filename: 0268_face_0.jpg, Predicted: youssef, Confidence: 77.4479125321155
# Filename: 0275_face_0.jpg, Predicted: bart, Confidence: 51.641198154311205
# Filename: 0282_face_0.jpg, Predicted: michiel, Confidence: 63.07964794305638
# Filename: 0282_face_1.jpg, Predicted: akif, Confidence: 62.656876818936055
# Filename: 0316_face_0.jpg, Predicted: raul, Confidence: 52.114263529339226
# Filename: 0344_face_0.jpg, Predicted: konrad, Confidence: 77.08802417365543
# Filename: 0377_face_1.jpg, Predicted: nelli, Confidence: 65.83726764767896
# Filename: 0377_face_2.jpg, Predicted: senne, Confidence: 39.67249427185911
# Filename: 0381_face_0.jpg, Predicted: senne, Confidence: 41.953410183776
# Filename: 0381_face_1.jpg, Predicted: raul, Confidence: 48.51177163101794
# Filename: 0381_face_2.jpg, Predicted: matthias, Confidence: 52.35694745187315
# Filename: 0398_face_0.jpg, Predicted: michiel, Confidence: 49.65190885326711
# Filename: 0398_face_1.jpg, Predicted: raul, Confidence: 40.700493084722396
# Filename: 0398_face_2.jpg, Predicted: youssef, Confidence: 69.89331055135756
# Filename: 0416_face_0.jpg, Predicted: seppe, Confidence: 41.60977982165694
# Filename: 0418_face_0.jpg, Predicted: nelli, Confidence: 45.72417198454841
# Filename: 0418_face_2.jpg, Predicted: seppe, Confidence: 54.34366678510456
# Filename: 0420_face_0.jpg, Predicted: seppe, Confidence: 52.28730414615202
# Filename: 0420_face_1.jpg, Predicted: michiel, Confidence: 61.23481786530515
# Filename: 0423_face_1.jpg, Predicted: akif, Confidence: 68.5052999298532
# Filename: 0427_face_0.jpg, Predicted: youssef, Confidence: 100.28032219689378
# Filename: 0435_face_0.jpg, Predicted: florian, Confidence: 69.0720500133987
# Filename: 0443_face_0.jpg, Predicted: youssef, Confidence: 79.56360931582779
# Filename: 0444_face_0.jpg, Predicted: seppe, Confidence: 63.348488359042655
# Filename: 0448_face_0.jpg, Predicted: florian, Confidence: 60.03352213840622
# Filename: 0450_face_0.jpg, Predicted: michiel, Confidence: 54.91243470618644
# Filename: 0452_face_0.jpg, Predicted: matthias, Confidence: 53.850594001502216
# Filename: 0452_face_3.jpg, Predicted: michiel, Confidence: 57.3748858991224
# Filename: 0454_face_0.jpg, Predicted: alper, Confidence: 48.36024613194838
# Filename: 0454_face_1.jpg, Predicted: alper, Confidence: 58.54305042336725
# Filename: 0456_face_0.jpg, Predicted: raul, Confidence: 54.06625514109038
# Filename: 0472_face_0.jpg, Predicted: konrad, Confidence: 64.79072562812549
# Filename: 0472_face_1.jpg, Predicted: florian, Confidence: 64.43460740456479
# Filename: 0481_face_0.jpg, Predicted: bart, Confidence: 54.86591341258103
# Filename: 0513_face_0.jpg, Predicted: michiel, Confidence: 95.13906055666241
# Filename: 0521_face_0.jpg, Predicted: lasse, Confidence: 42.51179327678006
# Filename: 0521_face_1.jpg, Predicted: senne, Confidence: 39.541221616087185
# Filename: 0521_face_3.jpg, Predicted: matthias, Confidence: 47.95781929496707
# Filename: 0584_face_1.jpg, Predicted: seppe, Confidence: 43.03675525645934
# Filename: 0589_face_0.jpg, Predicted: konrad, Confidence: 50.885948675385116
# Filename: 0590_face_0.jpg, Predicted: lasse, Confidence: 56.71757880586575
# Filename: 0592_face_0.jpg, Predicted: michiel, Confidence: 49.07971957386428
# Filename: 0594_face_0.jpg, Predicted: seppe, Confidence: 68.99810033218468
# Filename: 0596_face_0.jpg, Predicted: nelli, Confidence: 42.17391139754264
# Filename: 0599_face_0.jpg, Predicted: florian, Confidence: 37.35805095222129
# Filename: 0603_face_1.jpg, Predicted: alper, Confidence: 52.97629106165205
# Filename: 0605_face_0.jpg, Predicted: nelli, Confidence: 47.936166953169284
# Filename: 0605_face_1.jpg, Predicted: florian, Confidence: 54.17697225789066
# Filename: 0612_face_0.jpg, Predicted: alper, Confidence: 46.839285370490465
# Filename: 0612_face_1.jpg, Predicted: seppe, Confidence: 51.834126672255316
# Filename: 0614_face_0.jpg, Predicted: seppe, Confidence: 87.98659449804282
# Filename: 0615_face_1.jpg, Predicted: seppe, Confidence: 44.13263286849421
# Filename: 0624_face_0.jpg, Predicted: konrad, Confidence: 76.14840723510181
# Filename: 0638_face_1.jpg, Predicted: akif, Confidence: 53.741133441375624
# Filename: 0641_face_0.jpg, Predicted: matthias, Confidence: 63.27249061609383
# Filename: 0646_face_1.jpg, Predicted: michiel, Confidence: 63.62975389161828
# Filename: 0648_face_0.jpg, Predicted: bart, Confidence: 71.10338437662168
# Filename: 0664_face_0.jpg, Predicted: matthias, Confidence: 60.34502696652264
# Filename: 0664_face_1.jpg, Predicted: florian, Confidence: 64.33443979836494
# Filename: 0668_face_1.jpg, Predicted: youssef, Confidence: 56.35088183451818
# Filename: 0669_face_2.jpg, Predicted: matthias, Confidence: 43.33790046206515
# Filename: 0669_face_3.jpg, Predicted: youssef, Confidence: 31.990524750503187
# Filename: 0675_face_1.jpg, Predicted: nelli, Confidence: 75.85991831443977
# Filename: 0676_face_0.jpg, Predicted: matthias, Confidence: 53.23354131613108
# Filename: 0676_face_1.jpg, Predicted: youssef, Confidence: 59.29959489460714
# Filename: 0679_face_1.jpg, Predicted: raul, Confidence: 47.125421375334454
# Filename: 0698_face_0.jpg, Predicted: bart, Confidence: 32.725472280116534
# Filename: 0754_face_0.jpg, Predicted: florian, Confidence: 56.5366204558565
# Filename: 0757_face_0.jpg, Predicted: raul, Confidence: 67.20438229585605
# Filename: 0757_face_1.jpg, Predicted: seppe, Confidence: 61.94244197348788
# Filename: 0763_face_0.jpg, Predicted: daiane, Confidence: 67.21548231211905
# Filename: 0764_face_0.jpg, Predicted: michiel, Confidence: 77.79169467286002
# Filename: 0765_face_0.jpg, Predicted: youssef, Confidence: 80.77480861936256
# Filename: 0766_face_0.jpg, Predicted: alper, Confidence: 82.3823363258544
# Filename: 0770_face_0.jpg, Predicted: lasse, Confidence: 95.4703147570155
# Filename: 0772_face_0.jpg, Predicted: matthias, Confidence: 81.9344970731481
# Filename: 0779_face_0.jpg, Predicted: daiane, Confidence: 74.18236743317355
# Filename: 0779_face_1.jpg, Predicted: seppe, Confidence: 71.61628219339207
# Filename: 0786_face_0.jpg, Predicted: daiane, Confidence: 83.8992683126264
# Filename: 0786_face_1.jpg, Predicted: konrad, Confidence: 55.06060913178565
# Filename: 0790_face_0.jpg, Predicted: konrad, Confidence: 79.21370357400079
# Filename: 0792_face_0.jpg, Predicted: raul, Confidence: 88.50114956795322
# Filename: 0794_face_0.jpg, Predicted: konrad, Confidence: 70.46642567755866
# Filename: 0799_face_0.jpg, Predicted: senne, Confidence: 102.66563512503626
# Filename: 0805_face_0.jpg, Predicted: konrad, Confidence: 88.14109143567165
# Filename: 0808_face_0.jpg, Predicted: florian, Confidence: 79.90738718316203
# Filename: 0818_face_1.jpg, Predicted: florian, Confidence: 25.07685383021304
# Filename: 0822_face_0.jpg, Predicted: youssef, Confidence: 32.98645387756288
# Filename: 0822_face_1.jpg, Predicted: raul, Confidence: 33.86163369088703
# Filename: 0825_face_0.jpg, Predicted: youssef, Confidence: 79.12963740199744

# %%
def group_results_by_image(results):
    """
    Group individual face predictions into a list of predicted labels for each image.
    Args:
        results: List of dictionaries with filename, predicted label, and confidence.
                 Example: [{"filename": "0125_face_0.jpg", "predicted_label": "senne", ...}, ...]
    Returns:
        grouped_results: List of dictionaries with image filename and grouped predicted labels.
                         Example: [{"filename": "0125.jpg", "predicted_labels": ["senne", "matthias"]}]
    """
    grouped_data = {}

    for result in results:
        # Extract the original image filename (before "_face_X")
        base_filename = result["filename"].split("_face")[0]

        # Add the predicted label to the grouped data
        if base_filename not in grouped_data:
            grouped_data[base_filename] = []
        if result["predicted_label"] != "unknown":  # Skip "unknown" predictions if needed
            grouped_data[base_filename].append(result["predicted_label"].lower())  # Convert to lowercase

    # Convert grouped data to the desired format
    grouped_results = [{"filename": filename, "predicted_labels": labels} for filename, labels in grouped_data.items()]
    return grouped_results

# Example usage
grouped_results = group_results_by_image(results)

# Print grouped results
print(grouped_results)
# Out:
# [{'filename': '0037', 'predicted_labels': ['senne']}, {'filename': '0039', 'predicted_labels': ['senne', 'youssef', 'matthias']}, {'filename': '0040', 'predicted_labels': ['seppe', 'alper', 'seppe']}, {'filename': '0043', 'predicted_labels': ['seppe', 'michiel']}, {'filename': '0045', 'predicted_labels': ['alper']}, {'filename': '0051', 'predicted_labels': ['youssef']}, {'filename': '0058', 'predicted_labels': ['bart']}, {'filename': '0062', 'predicted_labels': ['konrad']}, {'filename': '0066', 'predicted_labels': ['seppe', 'matthias']}, {'filename': '0078', 'predicted_labels': ['youssef']}, {'filename': '0103', 'predicted_labels': ['nelli']}, {'filename': '0125', 'predicted_labels': ['raul']}, {'filename': '0139', 'predicted_labels': ['youssef']}, {'filename': '0160', 'predicted_labels': ['youssef']}, {'filename': '0161', 'predicted_labels': ['florian']}, {'filename': '0166', 'predicted_labels': ['akif']}, {'filename': '0168', 'predicted_labels': ['konrad']}, {'filename': '0174', 'predicted_labels': ['bart']}, {'filename': '0179', 'predicted_labels': ['alper']}, {'filename': '0194', 'predicted_labels': ['seppe', 'seppe']}, {'filename': '0221', 'predicted_labels': ['konrad']}, {'filename': '0226', 'predicted_labels': ['senne']}, {'filename': '0233', 'predicted_labels': ['matthias']}, {'filename': '0245', 'predicted_labels': ['seppe']}, {'filename': '0255', 'predicted_labels': ['nelli']}, {'filename': '0262', 'predicted_labels': ['raul', 'youssef', 'matthias']}, {'filename': '0268', 'predicted_labels': ['youssef']}, {'filename': '0275', 'predicted_labels': ['bart']}, {'filename': '0282', 'predicted_labels': ['michiel', 'akif']}, {'filename': '0316', 'predicted_labels': ['raul']}, {'filename': '0344', 'predicted_labels': ['konrad']}, {'filename': '0377', 'predicted_labels': ['nelli', 'senne']}, {'filename': '0381', 'predicted_labels': ['senne', 'raul', 'matthias']}, {'filename': '0398', 'predicted_labels': ['michiel', 'raul', 'youssef']}, {'filename': '0416', 'predicted_labels': ['seppe']}, {'filename': '0418', 'predicted_labels': ['nelli', 'seppe']}, {'filename': '0420', 'predicted_labels': ['seppe', 'michiel']}, {'filename': '0423', 'predicted_labels': ['akif']}, {'filename': '0427', 'predicted_labels': ['youssef']}, {'filename': '0435', 'predicted_labels': ['florian']}, {'filename': '0443', 'predicted_labels': ['youssef']}, {'filename': '0444', 'predicted_labels': ['seppe']}, {'filename': '0448', 'predicted_labels': ['florian']}, {'filename': '0450', 'predicted_labels': ['michiel']}, {'filename': '0452', 'predicted_labels': ['matthias', 'michiel']}, {'filename': '0454', 'predicted_labels': ['alper', 'alper']}, {'filename': '0456', 'predicted_labels': ['raul']}, {'filename': '0472', 'predicted_labels': ['konrad', 'florian']}, {'filename': '0481', 'predicted_labels': ['bart']}, {'filename': '0513', 'predicted_labels': ['michiel']}, {'filename': '0521', 'predicted_labels': ['lasse', 'senne', 'matthias']}, {'filename': '0584', 'predicted_labels': ['seppe']}, {'filename': '0589', 'predicted_labels': ['konrad']}, {'filename': '0590', 'predicted_labels': ['lasse']}, {'filename': '0592', 'predicted_labels': ['michiel']}, {'filename': '0594', 'predicted_labels': ['seppe']}, {'filename': '0596', 'predicted_labels': ['nelli']}, {'filename': '0599', 'predicted_labels': ['florian']}, {'filename': '0603', 'predicted_labels': ['alper']}, {'filename': '0605', 'predicted_labels': ['nelli', 'florian']}, {'filename': '0612', 'predicted_labels': ['alper', 'seppe']}, {'filename': '0614', 'predicted_labels': ['seppe']}, {'filename': '0615', 'predicted_labels': ['seppe']}, {'filename': '0624', 'predicted_labels': ['konrad']}, {'filename': '0638', 'predicted_labels': ['akif']}, {'filename': '0641', 'predicted_labels': ['matthias']}, {'filename': '0646', 'predicted_labels': ['michiel']}, {'filename': '0648', 'predicted_labels': ['bart']}, {'filename': '0664', 'predicted_labels': ['matthias', 'florian']}, {'filename': '0668', 'predicted_labels': ['you ...

# %%
import os
import pandas as pd

def create_submission_csv_from_grouped_results(grouped_results, output_csv_path, test_images_folder):
    """
    Create a Kaggle submission CSV file from grouped prediction results.
    Args:
        grouped_results: List of dictionaries with image filename and grouped labels.
        output_csv_path: Path to save the submission CSV file.
        test_images_folder: Folder containing all test images to ensure no image is missing.
    """
    # Get all filenames in the test images folder without extensions
    all_filenames = sorted(
        [os.path.splitext(filename)[0] for filename in os.listdir(test_images_folder) 
         if filename.endswith(('.jpg', '.jpeg', '.png'))]
    )
    
    # Map grouped results by filename for quick lookup
    grouped_dict = {group["filename"].split('.')[0]: ";".join(group["predicted_labels"]) for group in grouped_results}

    # Create submission data, ensuring every file has an entry
    submission_data = []
    for filename in all_filenames:
        label_name = grouped_dict.get(filename, "nothing")  # Default to "nothing" if no labels
        submission_data.append({"image": filename, "label_name": label_name})

    # Save to a CSV
    submission_df = pd.DataFrame(submission_data)
    submission_df.to_csv(output_csv_path, index=False)
    print(f"Submission file saved to {output_csv_path}")

# Example usage
test_images_folder = "../data/images/test_images/cleaned_images"
output_csv_path = "../submission.csv"
create_submission_csv_from_grouped_results(grouped_results, output_csv_path, test_images_folder)
# Out:
# Submission file saved to ../submission.csv
